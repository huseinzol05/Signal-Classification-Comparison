# %%
import tensorflow as tf
import numpy as np
import matplotlib.mlab
import scipy.io.wavfile
import scipy
import os
import time
from scipy import signal
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import sparse
sns.set()

# %%
def log_specgram(audio, sample_rate, window_size=20,
                 step_size=10, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    freqs, times, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False)
    return freqs, times, np.log(spec.T.astype(np.float32) + eps)

def pad_audio(samples, L=16000):
    if len(samples) >= L: return samples
    else: return np.pad(samples, pad_width=(L - len(samples), 0), mode='constant', constant_values=(0, 0))

def chop_audio(samples, L=16000, num=20):
    for i in range(num):
        beg = np.random.randint(0, len(samples) - L)
        yield samples[beg: beg + L]

# %%
folders = [i for i in os.listdir(os.getcwd())if i.find('.md') < 0 and i.find('.txt') < 0 and i.find('ipynb') < 0 and i.find('py')  < 0 and i.find('LICENSE') < 0 and i.find('_background_noise_') < 0]

# %%
new_sample_rate = 8000
Y = []
X = []
for i in folders:
    print(i)
    for k in os.listdir(os.getcwd()+'/'+i):
        sample_rate, samples = scipy.io.wavfile.read(os.path.join(os.getcwd(), i, k))
        samples = pad_audio(samples)
        if len(samples) > 16000:
            n_samples = chop_audio(samples)
        else: n_samples = [samples]
        for samples in n_samples:
            resampled = signal.resample(samples, int(new_sample_rate / sample_rate * samples.shape[0]))
            _, _, specgram = log_specgram(resampled, sample_rate=new_sample_rate)
            Y.append(i)
            X.append(scipy.misc.imresize(specgram,[45, 40]).flatten())
# Out:
# yes
# marvin
# off
# bed
# house
# up
# six
# go
# four
# nine
# left
# no
# three
# wow
# sheila
# right
# on
# five
# seven
# zero
# stop
# one
# down
# bird
# tree
# eight
# dog
# two
# cat

# %%
X = np.array(X)
print(X.shape)
len(Y)
# Out:
# (62979, 1800)
# 62979

# %%
import lightgbm as lgb
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import LabelEncoder
labels = np.unique(Y)
target = LabelEncoder().fit_transform(Y)
train_X, test_X, train_Y, test_Y = train_test_split(X, target, test_size = 0.2)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
params_lgd = {
    'boosting_type': 'dart',
    'objective': 'multiclass',
    'colsample_bytree': 0.4,
    'subsample': 0.8,
    'learning_rate': 0.1,
    'silent': False,
    'n_estimators': 10000,
    'reg_lambda': 0.0005,
    'device':'gpu'
    }
clf = lgb.LGBMClassifier(**params_lgd)
lasttime = time.time()
clf.fit(train_X,train_Y, eval_set=[(test_X,test_Y)], 
        eval_metric='logloss', early_stopping_rounds=20, verbose=True)
print('time taken to fit lgb:', time.time()-lasttime, 'seconds ')
# Out:
# /usr/local/lib/python3.5/dist-packages/lightgbm/basic.py:642: UserWarning: max_bin keyword has been found in `params` and will be ignored. Please use max_bin argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# /usr/local/lib/python3.5/dist-packages/lightgbm/basic.py:648: LGBMDeprecationWarning: The `max_bin` parameter is deprecated and will be removed in 2.0.12 version. Please use `params` to pass this parameter.
#   'Please use `params` to pass this parameter.', LGBMDeprecationWarning)
# [1]	valid_0's multi_logloss: 3.15526
# Training until validation scores don't improve for 20 rounds.
# [2]	valid_0's multi_logloss: 3.01132
# [3]	valid_0's multi_logloss: 2.89098
# [4]	valid_0's multi_logloss: 2.79342
# [5]	valid_0's multi_logloss: 2.70512
# [6]	valid_0's multi_logloss: 2.62507
# [7]	valid_0's multi_logloss: 2.55135
# [8]	valid_0's multi_logloss: 2.58867
# [9]	valid_0's multi_logloss: 2.5208
# [10]	valid_0's multi_logloss: 2.45682
# [11]	valid_0's multi_logloss: 2.39718
# [12]	valid_0's multi_logloss: 2.42141
# [13]	valid_0's multi_logloss: 2.36492
# [14]	valid_0's multi_logloss: 2.31165
# [15]	valid_0's multi_logloss: 2.26279
# [16]	valid_0's multi_logloss: 2.21751
# [17]	valid_0's multi_logloss: 2.1751
# [18]	valid_0's multi_logloss: 2.13462
# [19]	valid_0's multi_logloss: 2.09548
# [20]	valid_0's multi_logloss: 2.05903
# [21]	valid_0's multi_logloss: 2.07195
# [22]	valid_0's multi_logloss: 2.03659
# [23]	valid_0's multi_logloss: 2.00345
# [24]	valid_0's multi_logloss: 1.97242
# [25]	valid_0's multi_logloss: 1.94248
# [26]	valid_0's multi_logloss: 1.91324
# [27]	valid_0's multi_logloss: 1.88591
# [28]	valid_0's multi_logloss: 1.89757
# [29]	valid_0's multi_logloss: 1.87077
# [30]	valid_0's multi_logloss: 1.84562
# [31]	valid_0's multi_logloss: 1.84915
# [32]	valid_0's multi_logloss: 1.8241
# [33]	valid_0's multi_logloss: 1.79968
# [34]	valid_0's multi_logloss: 1.77704
# [35]	valid_0's multi_logloss: 1.78987
# [36]	valid_0's multi_logloss: 1.81193
# [37]	valid_0's multi_logloss: 1.78922
# [38]	valid_0's multi_logloss: 1.76635
# [39]	valid_0's multi_logloss: 1.74451
# [40]	valid_0's multi_logloss: 1.74119
# [41]	valid_0's multi_logloss: 1.75631
# [42]	valid_0's multi_logloss: 1.73522
# [43]	valid_0's multi_logloss: 1.7481
# [44]	valid_0's multi_logloss: 1.72703
# [45]	valid_0's multi_logloss: 1.7069
# [46]	valid_0's multi_logloss: 1.73277
# [47]	valid_0's multi_logloss: 1.71234
# [48]	valid_0's multi_logloss: 1.71185
# [49]	valid_0's multi_logloss: 1.72666
# [50]	valid_0's multi_logloss: 1.74284
# [51]	valid_0's multi_logloss: 1.72073
# [52]	valid_0's multi_logloss: 1.6997
# [53]	valid_0's multi_logloss: 1.71279
# [54]	valid_0's multi_logloss: 1.69261
# [55]	valid_0's multi_logloss: 1.67386
# [56]	valid_0's multi_logloss: 1.69038
# [57]	valid_0's multi_logloss: 1.67121
# [58]	valid_0's multi_logloss: 1.69185
# [59]	valid_0's multi_logloss: 1.71054
# [60]	valid_0's multi_logloss: 1.68945
# [61]	valid_0's multi_logloss: 1.70643
# [62]	valid_0's multi_logloss: 1.68586
# [63]	valid_0's multi_logloss: 1.66654
# [64]	valid_0's multi_logloss: 1.68179
# [65]	valid_0's multi_logloss: 1.69319
# [66]	valid_0's multi_logloss: 1.6732
# [67]	valid_0's multi_logloss: 1.65371
# [68]	valid_0's multi_logloss: 1.63514
# [69]	valid_0's multi_logloss: 1.64734
# [70]	valid_0's multi_logloss: 1.65407
# [71]	valid_0's multi_logloss: 1.66553
# [72]	valid_0's multi_logloss: 1.64718
# [73]	valid_0's multi_logloss: 1.62936
# [74]	valid_0's multi_logloss: 1.63837
# [75]	valid_0's multi_logloss: 1.62023
# [76]	valid_0's multi_logloss: 1.62124
# [77]	valid_0's multi_logloss: 1.62978
# [78]	valid_0's multi_logloss: 1.6413
# [79]	valid_0's multi_logloss: 1.62265
# [80]	valid_0's multi_logloss: 1.6047
# [81]	valid_0's multi_logloss: 1.61466
# [82]	valid_0's multi_logloss: 1.5972
# [83]	valid_0's multi_logloss: 1.60851
# [84]	valid_0's multi_logloss: 1.61911
# [85]	valid_0's multi_logloss: 1.63033
# [86]	valid_0's multi_logloss: 1.61251
# [87]	valid_0's multi_logloss: 1.59456
# [88]	valid_0's multi_logloss: 1.6073
# [89]	valid_0's multi_logloss: 1.61707
# [90]	valid_0's multi_logloss: 1.62752
# [91]	valid_0's multi_logloss: 1.64122
# [92]	valid_0's multi_logloss: 1.62263
# [93]	valid_0's multi_logloss: 1.6051
# [94]	valid_0's multi_logloss: 1.61485
# [95]	valid_0's multi_logloss: 1.62399
# [96]	valid_0's multi_logloss: 1.63271
# [97]	valid_0's multi_logloss: 1.61409
# [98]	valid_0's multi_logloss: 1.62419
# [99]	valid_0's multi_logloss: 1.60593
# [100]	valid_0's multi_logloss: 1.58879
# [101]	valid_0's multi_logloss: 1.60342
# [102]	valid_0's multi_logloss: 1.61225
# [103]	valid_0's multi_logloss: 1.62272
# [104]	valid_0's multi_logloss: 1.60484
# [105]	valid_0's multi_logloss: 1.61864
# [106]	valid_0's multi_logloss: 1.62976
# [107]	valid_0's multi_logloss: 1.64115
# [108]	valid_0's multi_logloss: 1.62186
# [109]	valid_0's multi_logloss: 1.63099
# [110]	valid_0's multi_logloss: 1.64117
# [111]	valid_0's multi_logloss: 1.62122
# [112]	valid_0's multi_logloss: 1.60224
# [113]	valid_0's multi_logloss: 1.58438
# [114]	valid_0's multi_logloss: 1.56755
# [115]	valid_0's multi_logloss: 1.55108
# [116]	valid_0's multi_logloss: 1.53526
# [117]	valid_0's multi_logloss: 1.54328
# [118]	valid_0's multi_logloss: 1.52806
# [119]	valid_0's multi_logloss: 1.53616
# [120]	valid_0's multi_logloss: 1.54554
# [121]	valid_0's multi_logloss: 1.55445
# [122]	valid_0's multi_logloss: 1.56443
# [123]	valid_0's multi_logloss: 1.5489
# [124]	valid_0's multi_logloss: 1.53273
# [125]	valid_0's multi_logloss: 1.54171
# [126]	valid_0's multi_logloss: 1.55009
# [127]	valid_0's multi_logloss: 1.53401
# [128]	valid_0's multi_logloss: 1.54254
# [129]	valid_0's multi_logloss: 1.52668
# [130]	valid_0's multi_logloss: 1.51199
# [131]	valid_0's multi_logloss: 1.51867
# [132]	valid_0's multi_logloss: 1.50397
# [133]	valid_0's multi_logloss: 1.48929
# [134]	valid_0's multi_logloss: 1.49908
# [135]	valid_0's multi_logloss: 1.48452
# [136]	valid_0's multi_logloss: 1.4966
# [137]	valid_0's multi_logloss: 1.50518
# [138]	valid_0's multi_logloss: 1.49023
# [139]	valid_0's multi_logloss: 1.47569
# [140]	valid_0's multi_logloss: 1.48516
# [141]	valid_0's multi_logloss: 1.4927
# [142]	valid_0's multi_logloss: 1.50066
# [143]	valid_0's multi_logloss: 1.48629
# [144]	valid_0's multi_logloss: 1.49308
# [145]	valid_0's multi_logloss: 1.4787
# [146]	valid_0's multi_logloss: 1.48845
# [147]	valid_0's multi_logloss: 1.49659
# [148]	valid_0's multi_logloss: 1.50599
# [149]	valid_0's multi_logloss: 1.49112
# [150]	valid_0's multi_logloss: 1.47716
# [151]	valid_0's multi_logloss: 1.48735
# [152]	valid_0's multi_logloss: 1.49684
# [153]	valid_0's multi_logloss: 1.48248
# [154]	valid_0's multi_logloss: 1.48913
# [155]	valid_0's multi_logloss: 1.47534
# [156]	valid_0's multi_logloss: 1.48368
# [157]	valid_0's multi_logloss: 1.48821
# [158]	valid_0's multi_logloss: 1.49661
# [159]	valid_0's multi_logloss: 1.50486
# [160]	valid_0's multi_logloss: 1.51319
# [161]	valid_0's multi_logloss: 1.49835
# [162]	valid_0's multi_logloss: 1.50548
# [163]	valid_0's multi_logloss: 1.49065
# [164]	valid_0's multi_logloss: 1.47676
# [165]	valid_0's multi_logloss: 1.46285
# [166]	valid_0's multi_logloss: 1.44936
# [167]	valid_0's multi_logloss: 1.43642
# [168]	valid_0's multi_logloss: 1.42341
# [169]	valid_0's multi_logloss: 1.41123
# [170]	valid_0's multi_logloss: 1.4191
# [171]	valid_0's multi_logloss: 1.40678
# [172]	valid_0's multi_logloss: 1.41429
# [173]	valid_0's multi_logloss: 1.40223
# [174]	valid_0's multi_logloss: 1.39085
# [175]	valid_0's multi_logloss: 1.37967
# [176]	valid_0's multi_logloss: 1.38521
# [177]	valid_0's multi_logloss: 1.39211
# [178]	valid_0's multi_logloss: 1.39903
# [179]	valid_0's multi_logloss: 1.3873
# [180]	valid_0's multi_logloss: 1.39353
# [181]	valid_0's multi_logloss: 1.38259
# [182]	valid_0's multi_logloss: 1.37153
# [183]	valid_0's multi_logloss: 1.36118
# [184]	valid_0's multi_logloss: 1.35096
# [185]	valid_0's multi_logloss: 1.35844
# [186]	valid_0's multi_logloss: 1.34827
# [187]	valid_0's multi_logloss: 1.33814
# [188]	valid_0's multi_logloss: 1.3285
# [189]	valid_0's multi_logloss: 1.33548
# [190]	valid_0's multi_logloss: 1.34206
# [191]	valid_0's multi_logloss: 1.33149
# [192]	valid_0's multi_logloss: 1.32173
# [193]	valid_0's multi_logloss: 1.31226
# [194]	valid_0's multi_logloss: 1.31811
# [195]	valid_0's multi_logloss: 1.32345
# [196]	valid_0's multi_logloss: 1.31423
# [197]	valid_0's multi_logloss: 1.31899
# [198]	valid_0's multi_logloss: 1.32489
# [199]	valid_0's multi_logloss: 1.31542
# [200]	valid_0's multi_logloss: 1.32193
# [201]	valid_0's multi_logloss: 1.3279
# [202]	valid_0's multi_logloss: 1.33399
# [203]	valid_0's multi_logloss: 1.32384
# [204]	valid_0's multi_logloss: 1.32897
# [205]	valid_0's multi_logloss: 1.3354
# [206]	valid_0's multi_logloss: 1.32476
# [207]	valid_0's multi_logloss: 1.33073
# [208]	valid_0's multi_logloss: 1.32019
# [209]	valid_0's multi_logloss: 1.32653
# [210]	valid_0's multi_logloss: 1.33226
# [211]	valid_0's multi_logloss: 1.33785
# [212]	valid_0's multi_logloss: 1.32733
# [213]	valid_0's multi_logloss: 1.31775
# Early stopping, best iteration is:
# [193]	valid_0's multi_logloss: 1.31226
# time taken to fit lgb: 2149.428333044052 seconds

# %%
predicted = clf.predict(test_X)
print('accuracy validation set: ', np.mean(predicted == test_Y))

# print scores
print(metrics.classification_report(test_Y, predicted, target_names = labels))
# Out:
# accuracy validation set:  0.722689742775
#              precision    recall  f1-score   support
#
#         bed       0.64      0.68      0.66       359
#        bird       0.82      0.74      0.78       327
#         cat       0.77      0.72      0.74       353
#         dog       0.78      0.59      0.67       340
#        down       0.67      0.67      0.67       457
#       eight       0.75      0.79      0.77       466
#        five       0.73      0.65      0.69       514
#        four       0.78      0.82      0.80       477
#          go       0.54      0.61      0.57       463
#       house       0.87      0.75      0.80       324
#        left       0.75      0.70      0.72       488
#      marvin       0.79      0.76      0.78       370
#        nine       0.70      0.75      0.72       447
#          no       0.70      0.57      0.63       518
#         off       0.71      0.74      0.72       450
#          on       0.66      0.66      0.66       466
#         one       0.72      0.75      0.73       485
#       right       0.80      0.73      0.76       453
#       seven       0.78      0.73      0.75       467
#      sheila       0.88      0.81      0.85       362
#         six       0.69      0.85      0.76       469
#        stop       0.77      0.73      0.75       452
#       three       0.68      0.71      0.70       461
#        tree       0.80      0.62      0.70       341
#         two       0.65      0.81      0.72       530
#          up       0.59      0.80      0.68       470
#         wow       0.80      0.71      0.76       358
#         yes       0.75      0.70      0.72       470
#        zero       0.76      0.78      0.77       459
#
# avg / total       0.73      0.72      0.72     12596
