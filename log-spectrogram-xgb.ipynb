# %%
import tensorflow as tf
import numpy as np
import matplotlib.mlab
import scipy.io.wavfile
import scipy
import os
import time
from scipy import signal
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import sparse
sns.set()

# %%
def log_specgram(audio, sample_rate, window_size=20,
                 step_size=10, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    freqs, times, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False)
    return freqs, times, np.log(spec.T.astype(np.float32) + eps)

def pad_audio(samples, L=16000):
    if len(samples) >= L: return samples
    else: return np.pad(samples, pad_width=(L - len(samples), 0), mode='constant', constant_values=(0, 0))

def chop_audio(samples, L=16000, num=20):
    for i in range(num):
        beg = np.random.randint(0, len(samples) - L)
        yield samples[beg: beg + L]

# %%
folders = [i for i in os.listdir(os.getcwd())if i.find('.md') < 0 and i.find('.txt') < 0 and i.find('ipynb') < 0 and i.find('py')  < 0 and i.find('LICENSE') < 0 and i.find('_background_noise_') < 0]

# %%
new_sample_rate = 8000
Y = []
X = []
for i in folders:
    print(i)
    for k in os.listdir(os.getcwd()+'/'+i):
        sample_rate, samples = scipy.io.wavfile.read(os.path.join(os.getcwd(), i, k))
        samples = pad_audio(samples)
        if len(samples) > 16000:
            n_samples = chop_audio(samples)
        else: n_samples = [samples]
        for samples in n_samples:
            resampled = signal.resample(samples, int(new_sample_rate / sample_rate * samples.shape[0]))
            _, _, specgram = log_specgram(resampled, sample_rate=new_sample_rate)
            Y.append(i)
            X.append(scipy.misc.imresize(specgram,[45, 40]).flatten())
# Out:
# yes
# marvin
# off
# bed
# house
# up
# six
# go
# four
# nine
# left
# no
# three
# wow
# sheila
# right
# on
# five
# seven
# zero
# stop
# one
# down
# bird
# tree
# eight
# dog
# two
# cat

# %%
X = np.array(X)
print(X.shape)
len(Y)
# Out:
# (62979, 1800)
# 62979

# %%
import xgboost as xgb
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import LabelEncoder
labels = np.unique(Y)
target = LabelEncoder().fit_transform(Y)
train_X, test_X, train_Y, test_Y = train_test_split(X, target, test_size = 0.2)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train_d = xgb.DMatrix(train_X, train_Y)
test_d = xgb.DMatrix(test_X, test_Y)
params_xgd = {
    'min_child_weight': 10.0,
    'max_depth': 7,
    'objective': 'multi:softprob',
    'max_delta_step': 1.8,
    'num_class': len(labels),
    'colsample_bytree': 0.4,
    'subsample': 0.8,
    'learning_rate': 0.1,
    'gamma': 0.65,
    'silent':False,
    'eval_metric': 'mlogloss',
    'tree_method':'gpu_hist'
}
model = xgb.train(params_xgd, train_d, 10000, evals=[(test_d, 'validation')], 
                  early_stopping_rounds=100, verbose_eval=5)
# Out:
# [0]	validation-mlogloss:3.2758
# Will train until validation-mlogloss hasn't improved in 100 rounds.
# [5]	validation-mlogloss:2.85859
# [10]	validation-mlogloss:2.50898
# [15]	validation-mlogloss:2.23018
# [20]	validation-mlogloss:2.02854
# [25]	validation-mlogloss:1.87272
# [30]	validation-mlogloss:1.75218
# [35]	validation-mlogloss:1.65266
# [40]	validation-mlogloss:1.57137
# [45]	validation-mlogloss:1.50541
# [50]	validation-mlogloss:1.44853
# [55]	validation-mlogloss:1.39895
# [60]	validation-mlogloss:1.35449
# [65]	validation-mlogloss:1.31792
# [70]	validation-mlogloss:1.28513
# [75]	validation-mlogloss:1.25347
# [80]	validation-mlogloss:1.22769
# [85]	validation-mlogloss:1.20271
# [90]	validation-mlogloss:1.17994
# [110]	validation-mlogloss:1.1072
# [115]	validation-mlogloss:1.09192
# [120]	validation-mlogloss:1.07794
# [125]	validation-mlogloss:1.06526
# [130]	validation-mlogloss:1.05304
# [135]	validation-mlogloss:1.04167
# [140]	validation-mlogloss:1.03059
# [145]	validation-mlogloss:1.02016
# [150]	validation-mlogloss:1.01023
# [155]	validation-mlogloss:1.00031
# [160]	validation-mlogloss:0.991287
# [165]	validation-mlogloss:0.982788
# [170]	validation-mlogloss:0.974511
# [175]	validation-mlogloss:0.965579
# [180]	validation-mlogloss:0.958002
# [185]	validation-mlogloss:0.951034
# [190]	validation-mlogloss:0.944018
# [195]	validation-mlogloss:0.937211
# [200]	validation-mlogloss:0.930677
# [205]	validation-mlogloss:0.924722
# [210]	validation-mlogloss:0.918548
# [215]	validation-mlogloss:0.912424
# [220]	validation-mlogloss:0.906882
# [225]	validation-mlogloss:0.901612
# [230]	validation-mlogloss:0.896058
# [235]	validation-mlogloss:0.89055
# [240]	validation-mlogloss:0.885946
# [245]	validation-mlogloss:0.881365
# [250]	validation-mlogloss:0.876796
# [255]	validation-mlogloss:0.872342
# [260]	validation-mlogloss:0.867836
# [265]	validation-mlogloss:0.864063
# [270]	validation-mlogloss:0.859708
# [275]	validation-mlogloss:0.855772
# [280]	validation-mlogloss:0.851737
# [285]	validation-mlogloss:0.84829
# [290]	validation-mlogloss:0.84504
# [295]	validation-mlogloss:0.841481
# [300]	validation-mlogloss:0.838062
# [305]	validation-mlogloss:0.83489
# [310]	validation-mlogloss:0.83195
# [315]	validation-mlogloss:0.828964
# [320]	validation-mlogloss:0.825926
# [325]	validation-mlogloss:0.823144
# [330]	validation-mlogloss:0.820165
# [335]	validation-mlogloss:0.81708
# [340]	validation-mlogloss:0.814429
# [345]	validation-mlogloss:0.811696
# [350]	validation-mlogloss:0.809299
# [355]	validation-mlogloss:0.806764
# [360]	validation-mlogloss:0.804715
# [365]	validation-mlogloss:0.802154
# [370]	validation-mlogloss:0.799757
# [375]	validation-mlogloss:0.797625
# [380]	validation-mlogloss:0.795367
# [385]	validation-mlogloss:0.793554
# [390]	validation-mlogloss:0.791415
# [395]	validation-mlogloss:0.789556
# [400]	validation-mlogloss:0.787962
# [405]	validation-mlogloss:0.786286
# [410]	validation-mlogloss:0.784708
# [415]	validation-mlogloss:0.78278
# [420]	validation-mlogloss:0.780755
# [425]	validation-mlogloss:0.779329
# [430]	validation-mlogloss:0.777733
# [435]	validation-mlogloss:0.776108
# [440]	validation-mlogloss:0.774456
# [445]	validation-mlogloss:0.77286
# [450]	validation-mlogloss:0.771389
# [455]	validation-mlogloss:0.770056
# [460]	validation-mlogloss:0.768713
# [465]	validation-mlogloss:0.7676
# [470]	validation-mlogloss:0.765951
# [475]	validation-mlogloss:0.764531
# [480]	validation-mlogloss:0.763165
# [485]	validation-mlogloss:0.761925
# [490]	validation-mlogloss:0.760756
# [495]	validation-mlogloss:0.75953
# [500]	validation-mlogloss:0.758527
# [505]	validation-mlogloss:0.757418
# [510]	validation-mlogloss:0.756452
# [515]	validation-mlogloss:0.755611
# [520]	validation-mlogloss:0.754348
# [525]	validation-mlogloss:0.753461
# [530]	validation-mlogloss:0.752494
# [535]	validation-mlogloss:0.751427
# [540]	validation-mlogloss:0.750686
# [545]	validation-mlogloss:0.749594
# [550]	validation-mlogloss:0.748606
# [555]	validation-mlogloss:0.747874
# [560]	validation-mlogloss:0.747033
# [565]	validation-mlogloss:0.745962
# [570]	validation-mlogloss:0.745145
# [575]	validation-mlogloss:0.744205
# [580]	validation-mlogloss:0.743565
# [585]	validation-mlogloss:0.742756
# [590]	validation-mlogloss:0.742205
# [595]	validation-mlogloss:0.741429
# [600]	validation-mlogloss:0.740828
# [605]	validation-mlogloss:0.740268
# [610]	validation-mlogloss:0.739502
# [615]	validation-mlogloss:0.73868
# [620]	validation-mlogloss:0.738016
# [625]	validation-mlogloss:0.737451
# [630]	validation-mlogloss:0.736862
# [635]	validation-mlogloss:0.736269
# [640]	validation-mlogloss:0.735625
# [645]	validation-mlogloss:0.734939
# [650]	validation-mlogloss:0.734548
# [655]	validation-mlogloss:0.734022
# [660]	validation-mlogloss:0.733556
# [665]	validation-mlogloss:0.732997
# [670]	validation-mlogloss:0.732708
# [675]	validation-mlogloss:0.732152
# [680]	validation-mlogloss:0.731579
# [685]	validation-mlogloss:0.731015
# [690]	validation-mlogloss:0.730376
# [695]	validation-mlogloss:0.729993
# [700]	validation-mlogloss:0.729656
# [705]	validation-mlogloss:0.729329
# [710]	validation-mlogloss:0.728786
# [715]	validation-mlogloss:0.728201
# [720]	validation-mlogloss:0.727911
# [725]	validation-mlogloss:0.72734
# [730]	validation-mlogloss:0.726798
# [735]	validation-mlogloss:0.726255
# [740]	validation-mlogloss:0.725813
# [745]	validation-mlogloss:0.72555
# [750]	validation-mlogloss:0.725276
# [755]	validation-mlogloss:0.724911
# [760]	validation-mlogloss:0.72455
# [765]	validation-mlogloss:0.724204
# [770]	validation-mlogloss:0.723887
# [775]	validation-mlogloss:0.7234
# [780]	validation-mlogloss:0.723135
# [785]	validation-mlogloss:0.722946
# [790]	validation-mlogloss:0.722694
# [795]	validation-mlogloss:0.722457
# [800]	validation-mlogloss:0.722126
# [805]	validation-mlogloss:0.721843
# [810]	validation-mlogloss:0.721614
# [815]	validation-mlogloss:0.721299
# [820]	validation-mlogloss:0.721143
# [825]	validation-mlogloss:0.720921
# [830]	validation-mlogloss:0.720634
# [835]	validation-mlogloss:0.720495
# [840]	validation-mlogloss:0.720178
# [845]	validation-mlogloss:0.720019
# [850]	validation-mlogloss:0.719801
# [855]	validation-mlogloss:0.719547
# [860]	validation-mlogloss:0.719352
# [865]	validation-mlogloss:0.719283
# [870]	validation-mlogloss:0.719227
# [875]	validation-mlogloss:0.719052
# [880]	validation-mlogloss:0.718767
# [885]	validation-mlogloss:0.718456
# [890]	validation-mlogloss:0.718281
# [895]	validation-mlogloss:0.717906
# [900]	validation-mlogloss:0.717877
# [905]	validation-mlogloss:0.717815
# [910]	validation-mlogloss:0.71755
# [915]	validation-mlogloss:0.71724
# [920]	validation-mlogloss:0.71702
# [925]	validation-mlogloss:0.716833
# [930]	validation-mlogloss:0.716557
# [935]	validation-mlogloss:0.71652
# [940]	validation-mlogloss:0.71624
# [945]	validation-mlogloss:0.716148
# [950]	validation-mlogloss:0.716035
# [955]	validation-mlogloss:0.715931
# [960]	validation-mlogloss:0.715935
# [965]	validation-mlogloss:0.715737
# [970]	validation-mlogloss:0.715509
# [975]	validation-mlogloss:0.715293
# [980]	validation-mlogloss:0.715219
# [985]	validation-mlogloss:0.715065
# [990]	validation-mlogloss:0.714847
# [995]	validation-mlogloss:0.714813
# [1000]	validation-mlogloss:0.714714
# [1005]	validation-mlogloss:0.714639
# [1010]	validation-mlogloss:0.714469
# [1015]	validation-mlogloss:0.71441
# [1020]	validation-mlogloss:0.714305
# [1025]	validation-mlogloss:0.714259
# [1030]	validation-mlogloss:0.713998
# [1035]	validation-mlogloss:0.713961
# [1040]	validation-mlogloss:0.713896
# [1045]	validation-mlogloss:0.713799
# [1050]	validation-mlogloss:0.71369
# [1055]	validation-mlogloss:0.713513
# [1060]	validation-mlogloss:0.713401
# [1065]	validation-mlogloss:0.713299
# [1070]	validation-mlogloss:0.713289
# [1075]	validation-mlogloss:0.713217
# [1080]	validation-mlogloss:0.713112
# [1085]	validation-mlogloss:0.713021
# [1090]	validation-mlogloss:0.712982
# [1095]	validation-mlogloss:0.7129
# [1100]	validation-mlogloss:0.71279
# [1105]	validation-mlogloss:0.712744
# [1110]	validation-mlogloss:0.712776
# [1115]	validation-mlogloss:0.712813
# [1120]	validation-mlogloss:0.712662
# [1125]	validation-mlogloss:0.712601
# [1130]	validation-mlogloss:0.712567
# [1135]	validation-mlogloss:0.712414
# [1140]	validation-mlogloss:0.712516
# [1145]	validation-mlogloss:0.712486
# [1150]	validation-mlogloss:0.712497
# [1155]	validation-mlogloss:0.71241
# [1160]	validation-mlogloss:0.712328
# [1165]	validation-mlogloss:0.712218
# [1170]	validation-mlogloss:0.712184
# [1175]	validation-mlogloss:0.712109
# [1180]	validation-mlogloss:0.711965
# [1185]	validation-mlogloss:0.71189
# [1190]	validation-mlogloss:0.711869
# [1195]	validation-mlogloss:0.711838
# [1200]	validation-mlogloss:0.711769
# [1205]	validation-mlogloss:0.711646
# [1210]	validation-mlogloss:0.711689
# [1215]	validation-mlogloss:0.711609
# [1220]	validation-mlogloss:0.711547
# [1225]	validation-mlogloss:0.711521
# [1230]	validation-mlogloss:0.711589
# [1235]	validation-mlogloss:0.711663
# [1240]	validation-mlogloss:0.711674
# [1245]	validation-mlogloss:0.71156
# [1250]	validation-mlogloss:0.711497
# [1255]	validation-mlogloss:0.711361
# [1260]	validation-mlogloss:0.711408
# [1265]	validation-mlogloss:0.711342
# [1270]	validation-mlogloss:0.711376
# [1275]	validation-mlogloss:0.711298
# [1280]	validation-mlogloss:0.711231
# [1285]	validation-mlogloss:0.711108
# [1290]	validation-mlogloss:0.711031
# [1295]	validation-mlogloss:0.711023
# [1300]	validation-mlogloss:0.710938
# [1305]	validation-mlogloss:0.710947
# [1310]	validation-mlogloss:0.710972
# [1315]	validation-mlogloss:0.710945
# [1320]	validation-mlogloss:0.710947
# [1325]	validation-mlogloss:0.711006
# [1330]	validation-mlogloss:0.710982
# [1335]	validation-mlogloss:0.711017
# [1340]	validation-mlogloss:0.711108
# [1345]	validation-mlogloss:0.711075
# [1350]	validation-mlogloss:0.711025
# [1355]	validation-mlogloss:0.71096
# [1360]	validation-mlogloss:0.710906
# [1365]	validation-mlogloss:0.710882
# [1370]	validation-mlogloss:0.710811
# [1375]	validation-mlogloss:0.710906
# [1380]	validation-mlogloss:0.71092
# [1385]	validation-mlogloss:0.710909
# [1390]	validation-mlogloss:0.710957
# [1395]	validation-mlogloss:0.710962
# [1400]	validation-mlogloss:0.710939
# [1405]	validation-mlogloss:0.710872
# [1410]	validation-mlogloss:0.710834
# [1415]	validation-mlogloss:0.710934
# [1420]	validation-mlogloss:0.71089
# [1425]	validation-mlogloss:0.710867
# [1430]	validation-mlogloss:0.710875
# [1435]	validation-mlogloss:0.710858
# [1440]	validation-mlogloss:0.71087
# [1445]	validation-mlogloss:0.710857
# [1450]	validation-mlogloss:0.710858
# [1455]	validation-mlogloss:0.71087
# [1460]	validation-mlogloss:0.710908
# [1465]	validation-mlogloss:0.710846
# [1470]	validation-mlogloss:0.710798
# Stopping. Best iteration:
# [1371]	validation-mlogloss:0.710787

# %%
predicted = np.argmax(model.predict(xgb.DMatrix(test_X),ntree_limit=model.best_ntree_limit),axis=1)
print('accuracy validation set: ', np.mean(predicted == test_Y))

# print scores
print(metrics.classification_report(test_Y, predicted, target_names = labels))
# Out:
# accuracy validation set:  0.801047951731
#              precision    recall  f1-score   support
#
#         bed       0.71      0.78      0.74       330
#        bird       0.85      0.83      0.84       348
#         cat       0.81      0.85      0.83       362
#         dog       0.76      0.70      0.73       351
#        down       0.77      0.74      0.75       442
#       eight       0.83      0.86      0.85       485
#        five       0.80      0.77      0.78       478
#        four       0.83      0.88      0.86       460
#          go       0.68      0.69      0.69       460
#       house       0.90      0.82      0.86       368
#        left       0.81      0.78      0.79       495
#      marvin       0.87      0.80      0.84       363
#        nine       0.81      0.80      0.80       455
#          no       0.76      0.74      0.75       468
#         off       0.77      0.78      0.78       464
#          on       0.78      0.74      0.76       447
#         one       0.76      0.82      0.79       418
#       right       0.86      0.80      0.83       491
#       seven       0.86      0.82      0.84       495
#      sheila       0.94      0.87      0.90       359
#         six       0.78      0.88      0.83       474
#        stop       0.84      0.80      0.82       489
#       three       0.78      0.80      0.79       476
#        tree       0.81      0.71      0.76       329
#         two       0.77      0.81      0.79       506
#          up       0.70      0.82      0.76       504
#         wow       0.80      0.82      0.81       330
#         yes       0.84      0.86      0.85       496
#        zero       0.82      0.84      0.83       453
#
# avg / total       0.80      0.80      0.80     12596
